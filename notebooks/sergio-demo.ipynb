# %%
import setup_notebook_environment

# %%
import pyciras

# %%
pyciras.run_repo_cloner(repo_urls=None,
                    chunk_size=100,
                    multiprocessing=True)

pyciras.run_mining(repo_urls=None,
               chunk_size=1,
               multiprocessing=False,
               persist_repos=True,  # Testa false, tar den bort nedladdade?
               stargazers=True,
               metadata=True,
               test=True,
               git=True,
               lint=True)
# Out:
# Output()
# [03/25/24 09:38:46] INFO                                                                              ]8;id=856093;file:///home/s/Skola/exjobb/github_metric_extractor/pyciras.py\pyciras.py]8;;\:]8;id=183874;file:///home/s/Skola/exjobb/github_metric_extractor/pyciras.py#91\91]8;;\
#                              Cloning 5 repositories
#                     INFO     Cloning will run with the current settings:                              ]8;id=377023;file:///home/s/Skola/exjobb/github_metric_extractor/pyciras.py\pyciras.py]8;;\:]8;id=576116;file:///home/s/Skola/exjobb/github_metric_extractor/pyciras.py#93\93]8;;\
#                               - chunk_size=100, multiprocessing=True
#
#
#                              Log directory
#                              /home/s/Skola/exjobb/github_metric_extractor/out/logs
#
#                              Repositories direvtory
#                              /home/s/Skola/exjobb/github_metric_extractor/out/repositories
# ...

# %%
import pandas as pd

# %% [markdown]
# ### Metadata

# %%
pd.read_csv('../out/data/2024-03-25_09-38/metadata.csv')
# Out:
#               repo                 archivedAt                  createdAt  \
# 0      TDD-Hangman                        NaN  2023-10-07 10:24:24+00:00
# 1           Tailor                        NaN  2023-02-10 09:30:09+00:00
# 2  amalfi-artifact                        NaN  2022-01-06 13:51:27+00:00
# 3  conala-baseline                        NaN  2018-06-08 20:28:23+00:00
# 4             sadl  2022-06-20 11:33:47+00:00  2018-11-27 04:58:24+00:00
#
#                                          description  diskUsage  forkCount  \
# 0  This is a simple hangman game. It was built co...   0.254883          0
# 1  Learning graph-based code representations for ...  18.820312          4
# 2  Artifact accompanying our ICSE '22 paper "Prac...   3.648438          8
# 3  Baseline for the Conala: Code/Natural Language...   0.020508         15
# 4  Code release of a paper "Guiding Deep Learning...   5.458008         20
#
# ...

# %% [markdown]
# ### Git Data

# %%
pd.read_csv('../out/data/2024-03-25_09-38/git.csv')
# Out:
#               repo  average_dmm_method_cyclomatic_complexity  \
# 0      TDD-Hangman                                  1.000000
# 1           Tailor                                  0.539400
# 2  amalfi-artifact                                  0.188679
# 3  conala-baseline                                  0.481633
# 4             sadl                                  0.642612
#
#    average_dmm_method_lines_of_code  average_dmm_method_number_of_parameters  \
# 0                          0.974350                                 0.985952
# 1                          0.298139                                 0.705998
# 2                          0.088050                                 0.188679
# 3                          0.542857                                 0.947959
# 4                          0.116838                                 0.305842
#
#    average_files_modified_per_commit  average_lines_added_per_commit  \
# ...

# %% [markdown]
# ### Lint Data

# %%
pd.read_csv('../out/data/2024-03-25_09-38/lint.csv')
# Out:
#             repo                       date  \
# 0    TDD-Hangman  2023-03-02 14:32:00+00:00
# 1    TDD-Hangman  2023-03-02 14:38:16+00:00
# 2    TDD-Hangman  2023-03-02 15:00:58+00:00
# 3    TDD-Hangman  2023-03-02 15:09:41+00:00
# 4    TDD-Hangman  2023-03-02 15:24:42+00:00
# ..           ...                        ...
# 118         sadl  2019-02-26 02:01:32+00:00
# 119         sadl  2019-08-30 01:14:26+00:00
# 120         sadl  2019-09-27 00:35:04+00:00
# 121         sadl  2019-09-27 00:37:29+00:00
# 122         sadl  2021-04-28 05:43:30+00:00
#
#                                   commit_hash  stats.avg_mccabe_complexity  \
# 0    6f85d829c16b3c23516b0992a693f20a0e8a3f05                        2.000
# 1    1ad98e363d3e90815824c631e671199ae00a7816                        0.000
# 2    2237723d4ce9493fe65f86948a48e5f28c21b66d                        0.000
# 3    86819b75ea7a61d1545427e5a073b74aa0b6ed6e                        0.000
# ...

# %% [markdown]
# ### Test Data

# %%
pd.read_csv('../out/data/2024-03-25_09-38/test.csv')
# Out:
#             repo                       date  test-classes test-frameworks  \
# 0    TDD-Hangman  2023-03-02 14:32:00+00:00             0              ()
# 1    TDD-Hangman  2023-03-02 14:38:16+00:00             0              ()
# 2    TDD-Hangman  2023-03-02 15:00:58+00:00             1   ('unittest',)
# 3    TDD-Hangman  2023-03-02 15:09:41+00:00             1   ('unittest',)
# 4    TDD-Hangman  2023-03-02 15:24:42+00:00             1   ('unittest',)
# ..           ...                        ...           ...             ...
# 118         sadl  2019-02-26 02:01:32+00:00             0              ()
# 119         sadl  2019-08-30 01:14:26+00:00             0              ()
# 120         sadl  2019-09-27 00:35:04+00:00             0              ()
# 121         sadl  2019-09-27 00:37:29+00:00             0              ()
# 122         sadl  2021-04-28 05:43:30+00:00             0              ()
#
#      test-functions  test-to-code-ratio
# ...

# %% [markdown]
# ### Stargazers Data

# %%
pd.read_csv('../out/data/2024-03-25_09-38/stargazers.csv')
# Out:
#                           date  Tailor  amalfi-artifact  conala-baseline  sadl
# 0    2018-06-18 15:41:20+00:00       0                0                1     0
# 1    2018-06-18 19:28:53+00:00       0                0                2     0
# 2    2018-06-19 00:10:06+00:00       0                0                3     0
# 3    2018-06-19 03:17:05+00:00       0                0                4     0
# 4    2018-06-19 11:03:33+00:00       0                0                5     0
# ..                         ...     ...              ...              ...   ...
# 164  2024-02-25 18:28:26+00:00      31               31               60    43
# 165  2024-02-28 06:02:13+00:00      32               31               60    43
# 166  2024-03-11 06:25:19+00:00      33               31               60    43
# 167  2024-03-13 10:19:16+00:00      33               32               60    43
# 168  2024-03-22 14:23:36+00:00      34               32               60    43
#
# [169 rows x 5 columns]
